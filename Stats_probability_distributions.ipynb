# %% [markdown]
# <a href="https://colab.research.google.com/github/AzadMehedi/Statistics/blob/main/Stats_probability_distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()
sns.set_context('notebook')

# %% [markdown]
# # Normal Distribution
# ### Generate Random values

# %%
# if you don't want to get the same random number again then,
np.random.seed(0)
x_rand = np.random.normal(loc=0, scale=1.0, size=1000) # loc=mean, standard deviation=scale

# %% [markdown]
# ### Visualization

# %%
# using matplotlib
plt.hist(x_rand, bins=20)
plt.show()

# %%
# using seaborn
sns.histplot(x_rand, kde=False, bins =20)
# sns.histplot(data=x_rand, kde=False)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(x_rand, kde=False, bins =100)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.distplot(x_rand)
plt.show()

# %%
sns.distplot(x_rand, kde=False)
plt.show()

# %%
sns.distplot(x_rand, fit=stats.norm)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x_rand, fit=stats.norm, kde=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Distribution Fitting

# %%
stats.norm.fit(x_rand)
# Out:
# (-0.045256707490195384, 0.9870331586690257)

# %%
loc, scale = stats.norm.fit(x_rand)
loc, scale
# Out:
# (-0.045256707490195384, 0.9870331586690257)

# %% [markdown]
# ### Probability Density Function(PDF)

# %%
# linearly spaced values of x
x = np.linspace(-5,5,100)
# np.linspace(start=-5, stop=5, num=100)

# %%
# pdf
stats.norm.pdf(x, loc=loc, scale=scale)
# Out:
# array([1.36377079e-06, 2.26762342e-06, 3.73123130e-06, 6.07554296e-06,
#        9.78970727e-06, 1.56101114e-05, 2.46316771e-05, 3.84621583e-05,
#        5.94326377e-05, 9.08799428e-05, 1.37519021e-04, 2.05925051e-04,
#        3.05145719e-04, 4.47462933e-04, 6.49319634e-04, 9.32420238e-04,
#        1.32500200e-03, 1.86325829e-03, 2.59287318e-03, 3.57059979e-03,
#        4.86578328e-03, 6.56169491e-03, 8.75650888e-03, 1.15637218e-02,
#        1.51117920e-02, 1.95427638e-02, 2.50096541e-02, 3.16724073e-02,
#        3.96922893e-02, 4.92246808e-02, 6.04103505e-02, 7.33654335e-02,
#        8.81705006e-02, 1.04859265e-01, 1.23407627e-01, 1.43723862e-01,
#        1.65640846e-01, 1.88911192e-01, 2.13206099e-01, 2.38118559e-01,
#        2.63171316e-01, 2.87829660e-01, 3.11518773e-01, 3.33644975e-01,
#        3.53619853e-01, 3.70885945e-01, 3.84942443e-01, 3.95369267e-01,
#        4.01847900e-01, 4.04177547e-01, 4.02285474e-01, 3.96230775e-01,
#        3.86201310e-01, 3.72504023e-01, 3.55549342e-01, 3.35830763e-01,
#        3.13901043e-01, 2.90346589e-01, 2.65761694e-01, 2.40724185e-01,
#        2.15773821e-01, 1.91394505e-01, 1.68000999e-01, 1.45930460e-01,
#        1.25438751e-01, 1.06701169e-01, 8.98169540e-02, 7.48168040e-02,
#        6.16725162e-02, 5.03078630e-02, 4.06098847e-02, 3.24398868e-02,
#        2.56435761e-02, 2.00599357e-02, 1.55285951e-02, 1.18956036e-02,
#        9.01763159e-03, 6.76472550e-03, 5.02180164e-03, 3.68910160e-03,
#        2.68184309e-03, 1.92929126e-03, 1.37345336e-03, 9.67568505e-04,
#        6.74529916e-04, 4.65342151e-04, 3.17683938e-04, 2.14619811e-04,
#        1.43481545e-04, 9.49235486e-05, 6.21446253e-05, 4.02610288e-05,
#        2.58117737e-05, 1.63757996e-05, 1.02810830e-05, 6.38744104e-06,
#        3.92705179e-06, 2.38923044e-06, 1.43847108e-06, 8.57029790e-07])
